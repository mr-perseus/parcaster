# %% [markdown]
# Import Library

# %%
import json as json

# %%
metadata = {}
parking_sg={}
fields={}

metadata['parking_sg'] = parking_sg
parking_sg['fields'] = fields

P24={}
P24['label'] = 'Bahnhof'
P24['max_cap'] = 275
fields['P24'] = P24

P44={}
P44['label'] = 'Brühltor'
P44['max_cap'] = 448
fields['P44'] = P44

P42={}
P42['label'] = 'Burggraben'
P42['max_cap'] = 337
fields['P42'] = P42

P23={}
P23['label'] = 'Manor'
P23['max_cap'] = 132
fields['P23'] = P23

P33={}
P33['label'] = 'Einstein'
P33['max_cap'] = 175
fields['P33'] = P33

P25={}
P25['label'] = 'Kreuzbleiche'
P25['max_cap'] = 371
fields['P25'] = P25

P21={}
P21['label'] = 'Neumarkt'
P21['max_cap'] = 274
fields['P21'] = P21

P31={}
P31['label'] = 'Oberer Graben'
P31['max_cap'] = 138
fields['P31'] = P31

P54={}
P54['label'] = 'OLMA Messen'
P54['max_cap'] = None
fields['P54'] = P54

P53={}
P53['label'] = 'OLMA Parkplatz'
P53['max_cap'] = 110
fields['P53'] = P53

P32={}
P32['label'] = 'Raiffeisen'
P32['max_cap'] = 96
fields['P32'] = P32

P22={}
P22['label'] = 'Rathaus'
P22['max_cap'] = 83
fields['P22'] = P22

P52={}
P52['label'] = 'Spelterini'
P52['max_cap'] = 155
fields['P52'] = P52

P51={}
P51['label'] = 'Stadtpark AZSG'
P51['max_cap'] = 88
fields['P51'] = P51

P43={}
P43['label'] = 'Spisertor'
P43['max_cap'] = 32
fields['P43'] = P43

P41={}
P41['label'] = 'Unterer Graben'
P41['max_cap'] = None
fields['P41'] = P41

datetime={}
datetime['label'] = 'Zeitpunkt'
datetime['description'] = 'Beobachtungszeitpunkt'
fields['datetime'] = datetime

ferien={}
ferien['label'] = 'Schulferien'
ferien['description'] = 'Schulferien im Kanton St. Gallen'
fields['ferien'] = ferien

feiertag={}
feiertag['label'] = 'Feiertage'
feiertag['description'] = 'Feiertage in der Stadt St. Gallen'
fields['feiertag'] = feiertag

covid_19={}
covid_19['label'] = 'Covid-19'
covid_19['description'] = 'Covid-19-Massnahmen in Kraft'
fields['covid_19'] = covid_19

olma_offa={}
olma_offa['label'] = 'OLMA/OFFA'
olma_offa['description'] = 'OLMA oder OFFA findet statt'
fields['olma_offa'] = olma_offa

temperature_2m_max={}
temperature_2m_max['label'] = 'Maximaltemperatur'
temperature_2m_max['description'] = 'Maximale Tagestemperatur 2 Meter über Boden gemessen'
fields['temperature_2m_max'] = temperature_2m_max

temperature_2m_min={}
temperature_2m_min['label'] = 'Minimaltemperatur'
temperature_2m_min['description'] = 'Minimale Tagestemperatur 2 Meter über Boden gemessen'
fields['temperature_2m_min'] = temperature_2m_min

rain_sum={}
rain_sum['label'] = 'Regen'
rain_sum['description'] = 'Tagessumme Regenmenge in mm'
fields['rain_sum'] = rain_sum

snowfall_sum={}
snowfall_sum['label'] = 'Schneefall'
snowfall_sum['description'] = 'Tagessumme Schneemenge in mm'
fields['snowfall_sum'] = snowfall_sum

print(json.dumps(metadata, indent=4, ensure_ascii=False))
# Out:
# {
#     "parking_sg": {
#         "fields": {
#             "P24": {
#                 "label": "Bahnhof",
#                 "max_cap": 275
#             },
#             "P44": {
#                 "label": "Brühltor",
#                 "max_cap": 448
#             },
#             "P42": {
#                 "label": "Burggraben",
#                 "max_cap": 337
#             },
#             "P23": {
#                 "label": "Manor",
#                 "max_cap": 132
#             },
#             "P33": {
#                 "label": "Einstein",
#                 "max_cap": 175
#             },
#             "P25": {
#                 "label": "Kreuzbleiche",
#                 "max_cap": 371
#             },
#             "P21": {
#                 "label": "Neumarkt",
#                 "max_cap": 274
#             },
#             "P31": {
#                 "label": "Oberer Graben",
#                 "max_cap": 138
#             },
#             "P54": {
# ...

# %%
with open('metadata.json', 'w', encoding='utf8') as f:
    json.dump(metadata, f, indent=4, ensure_ascii=False)
